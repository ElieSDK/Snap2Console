# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/es/Documents/Project/VG/game_dataset_cleaned.csv')

# %%
df.shape
# Out:
# (232595, 23)

# %%
pd.set_option("display.max.columns", None)

# %%
df.head()
# Out:
#    id                     name   category release_date     rating  \
# 0   1  Thief II: The Metal Age  main_game   2000-03-21  87.197770
# 1   2  Thief: The Dark Project  main_game   1998-11-30  86.633969
# 2   3    Thief: Deadly Shadows  main_game   2004-05-25  81.896309
# 3   4                    Thief  main_game   2014-02-25  69.898552
# 4   5            Baldur's Gate  main_game   1998-12-21  85.799533
#
#    aggregated_rating                                 genres  \
# 0          90.000000  ['Shooter', 'Simulator', 'Adventure']
# 1          70.000000             ['Simulator', 'Adventure']
# 2          83.000000  ['Shooter', 'Simulator', 'Adventure']
# 3          63.642857               ['Shooter', 'Adventure']
# 4                NaN                 ['Role-playing (RPG)']
#
#                              themes               franchise  \
# 0  ['Action', 'Fantasy', 'Stealth']                     NaN
# 1  ['Action', 'Fantasy', 'Stealth']                     NaN
# 2  ['Action', 'Fantasy', 'Stealth']                     NaN
# 3  ['Action', 'Stealth', 'Sandbox']                     NaN
# 4         ['Fantasy', 'Open world']  ['Dungeons & Dragons']
#
#               series                  main_developers supporting_developers  \
# 0          ['Thief']        ['Looking Glass Studios']                   NaN
# 1          ['Thief']        ['Looking Glass Studios']                   NaN
# 2          ['Thief']                    ['Ion Storm']                   NaN
# 3          ['Thief']               ['Eidos Montréal']                   NaN
# 4  ["Baldur's Gate"]  ['BioWare', 'BioWare Edmonton']                   NaN
#
#                                           publishers  \
# 0  ['Square Enix', 'Eidos Interactive', 'Eidos Mo...
# 1          ['Activision Value', 'Eidos Interactive']
# 2  ['Square Enix', 'Eidos Interactive', 'Eidos Mo...
# 3  ['Feral Interactive', 'Eidos Montréal', 'Squar...
# 4  ['Interplay Entertainment', 'Black Isle Studios']
#
#                                            platforms  \
# 0                         ['PC (Microsoft Windows)']
# 1                         ['PC (Microsoft Windows)']
# 2                 ['Xbox', 'PC (Microsoft Windows)']
# 3  ['PlayStation 3', 'PlayStation 4', 'PC (Micros...
# 4  ['Linux', 'PC (Microsoft Windows)', 'iOS', 'Mac']
#
#                 player_perspectives                         game_modes  \
# 0                  ['First person']                  ['Single player']
# 1                  ['First person']                  ['Single player']
# 2  ['First person', 'Third person']                  ['Single player']
# 3                  ['First person']                  ['Single player']
# 4         ['Bird view / Isometric']  ['Single player', 'Co-operative']
#
#           game_engines                                      similar_games  \
# 0      ['Dark Engine']  [2, 3, 47823, 4, 55038, 9377, 105049, 36198, 4...
# 1      ['Dark Engine']  [1, 533, 3, 4, 11118, 3025, 5647, 41, 9377, 3188]
# 2  ['Unreal Engine 1']  [1, 9377, 2, 11118, 19441, 4, 533, 3025, 41, 9...
# 3  ['Unreal Engine 3']  [5647, 3188, 1121, 3025, 1877, 19441, 9377, 1,...
# 4  ['Infinity Engine']  [19164, 19698, 81249, 103303, 23651, 49414, 11...
#
#                                             keywords  \
# 0  ['ghosts', 'thief', 'death', 'swordplay', 'ste...
# 1  ['ghosts', 'assassin', 'basketball', 'medieval...
# 2  ['ghosts', 'assassin', 'minigames', 'thief', '...
# 3  ['thief', 'steampunk', 'blackjack', 'action-ad...
# 4                                                NaN
#
#                                            cover_url  \
# 0  https://images.igdb.com/igdb/image/upload/t_co...
# 1  https://images.igdb.com/igdb/image/upload/t_co...
# 2  https://images.igdb.com/igdb/image/upload/t_co...
# 3  https://images.igdb.com/igdb/image/upload/t_co...
# 4  https://images.igdb.com/igdb/image/upload/t_co...
#
#                                              summary  \
# 0  The ultimate thief is back! Tread softly as yo...
# 1  Thief is a first-person stealth game that like...
# 2  In the third instalment of the Thief series, m...
# 3  There is a rising tide of fear in The City. Ha...
# 4  Baldur's Gate is a fantasy role-playing video ...
#
#                                      screenshot_urls  \
# 0  ['https://images.igdb.com/igdb/image/upload/t_...
# 1  ['https://images.igdb.com/igdb/image/upload/t_...
# 2  ['https://images.igdb.com/igdb/image/upload/t_...
# 3  ['https://images.igdb.com/igdb/image/upload/t_...
# 4  ['https://images.igdb.com/igdb/image/upload/t_...
#
#                                         artwork_urls
# 0  ['https://images.igdb.com/igdb/image/upload/t_...
# 1  ['https://images.igdb.com/igdb/image/upload/t_...
# 2                                                NaN
# 3  ['https://images.igdb.com/igdb/image/upload/t_...
# 4                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232595 entries, 0 to 232594
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   id                     232595 non-null  int64
#  1   name                   232595 non-null  object
#  2   category               232595 non-null  object
#  3   release_date           179516 non-null  object
#  4   rating                 28787 non-null   float64
#  5   aggregated_rating      13709 non-null   float64
#  6   genres                 211627 non-null  object
#  7   themes                 143305 non-null  object
#  8   franchise              15118 non-null   object
#  9   series                 31377 non-null   object
#  10  main_developers        102113 non-null  object
#  11  supporting_developers  2492 non-null    object
#  12  publishers             99841 non-null   object
#  13  platforms              193690 non-null  object
#  14  player_perspectives    93537 non-null   object
#  15  game_modes             158869 non-null  object
#  16  game_engines           36517 non-null   object
#  17  similar_games          212326 non-null  object
#  18  keywords               97516 non-null   object
#  19  cover_url              205858 non-null  object
#  20  summary                232595 non-null  object
#  21  screenshot_urls        195208 non-null  object
#  22  artwork_urls           120860 non-null  object
# dtypes: float64(2), int64(1), object(20)
# memory usage: 40.8+ MB

# %%
df.describe(include=object)
# Out:
#           name   category release_date     genres      themes  franchise  \
# count   232595     232595       179516     211627      143305      15118
# unique  223575          5        12445       3379        2247       2540
# top     Tetris  main_game   2025-12-31  ['Indie']  ['Action']  ['Mario']
# freq        32     228390         1695      19202       59644        220
#
#                 series main_developers supporting_developers    publishers  \
# count            31377          102113                  2492         99841
# unique            9049           43538                  1841         38031
# top     ['Tamagotchi']      ['Konami']         ['ENTERGRAM']  ['Nintendo']
# freq                99             672                    22          1188
#
#                          platforms        player_perspectives  \
# count                       193690                      93537
# unique                        5613                         82
# top     ['PC (Microsoft Windows)']  ['Bird view / Isometric']
# freq                         83146                      22818
#
#                game_modes game_engines  \
# count              158869        36517
# unique                 50         1563
# top     ['Single player']    ['Unity']
# freq               124049        11849
#
#                                             similar_games  \
# count                                              212326
# unique                                              73759
# top     [113895, 105233, 111130, 32902, 119121, 40524,...
# freq                                                 8105
#
#                             keywords  \
# count                          97516
# unique                         59032
# top     ['nudity', 'sexual content']
# freq                            1783
#
#                                                 cover_url  \
# count                                              205858
# unique                                             205858
# top     https://images.igdb.com/igdb/image/upload/t_co...
# freq                                                    1
#
#                                                   summary  \
# count                                              232595
# unique                                             230208
# top     Meet over 50 pretty anime girls in this relaxi...
# freq                                                   51
#
#                                           screenshot_urls  \
# count                                              195208
# unique                                             195208
# top     ['https://images.igdb.com/igdb/image/upload/t_...
# freq                                                    1
#
#                                              artwork_urls
# count                                              120860
# unique                                             120860
# top     ['https://images.igdb.com/igdb/image/upload/t_...
# freq                                                    1

# %%
'''
Distribution of ratings and aggregated ratings.
Top developers and publishers by number of games.
Platforms and which genres are most common on them.
Ratings by genre, platform, or category.
Missing data per column (which features are incomplete).
Relationships between similar games or franchises.
Keyword trends in highly rated games.
Game modes and player perspectives distribution.
'''
# Out:
# '\nNumber of games released over time (per year).\nDistribution of ratings and aggregated ratings.\nPopularity of genres, themes, and keywords.\nTop developers and publishers by number of games.\nPlatforms and which genres are most common on them.\nRatings by genre, platform, or category.\nMissing data per column (which features are incomplete).\nRelationships between similar games or franchises.\nKeyword trends in highly rated games.\nGame modes and player perspectives distribution.\n'

# %%
df['category'].value_counts()
# Out:
# category
# main_game               228390
# expanded_game             1543
# remake                    1179
# remaster                  1091
# standalone_expansion       392
# Name: count, dtype: int64

# %%
tg = df['genres'].value_counts().head(10)
tg
# Out:
# genres
# ['Indie']                                       19202
# ['Adventure', 'Indie']                          16785
# ['Adventure']                                   10342
# ['Puzzle']                                       7076
# ['Simulator']                                    6141
# ['Role-playing (RPG)']                           5044
# ['Role-playing (RPG)', 'Adventure', 'Indie']     4999
# ['Strategy', 'Indie']                            4865
# ['Simulator', 'Indie']                           4688
# ['Arcade']                                       4610
# Name: count, dtype: int64

# %%
themes = df['themes'].value_counts().head(20)
themes
# Out:
# themes
# ['Action']                       59644
# ['Fantasy']                       6645
# ['Action', 'Science fiction']     6092
# ['Erotic']                        4800
# ['Action', 'Fantasy']             4614
# ['Horror']                        4204
# ['Science fiction']               3923
# ['Educational']                   2838
# ['Comedy']                        2502
# ['Kids']                          2310
# ['Action', 'Horror']              2044
# ['Action', 'Comedy']              1704
# ['Mystery']                       1681
# ['Romance']                       1313
# ['Party']                         1262
# ['Non-fiction']                   1121
# ['Business']                       927
# ['Action', 'Party']                808
# ['Historical']                     789
# ['Action', 'Erotic']               779
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(themes.index, themes.values)
plt.xticks(rotation=45, ha='right')
plt.title('Most Popular Themes')
plt.show()

# %%
#Let's remove Action
themes2 = themes.iloc[1:]

plt.bar(themes2.index, themes2.values)
plt.xticks(rotation=45, ha='right')
plt.title('Most Popular Themes')
plt.show()

# %%
plt.bar(tg.index, tg.values)
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Most Popular Genres')
plt.show()

# %%
#Number of games released over time (per year)
gy = df['release_date'].str.slice(0,4).value_counts().head(25)
#gy_sorted = gy.sort_values(ascending=False)
gy_sorted = gy.sort_index(ascending=False)
gy_sorted = gy_sorted.iloc[1:] #remove 2025
gy_sorted
# Out:
# release_date
# 2024    18338
# 2023    15338
# 2022    12115
# 2021    12750
# 2020    10600
# 2019     9448
# 2018    10568
# 2017     9770
# 2016     7240
# 2015     5166
# 2014     3992
# 2013     3058
# 2012     2878
# 2011     2763
# 2010     2863
# 2009     2722
# 2008     2324
# 2007     2103
# 2006     1952
# 2005     1779
# 2002     1681
# 2001     1671
# 2000     1642
# 1995     1623
# Name: count, dtype: int64

# %%
plt.bar(gy_sorted.index, gy_sorted.values)
plt.xticks(rotation=45, ha='right')
plt.title('Number of games released over time (per year)')
plt.show()
